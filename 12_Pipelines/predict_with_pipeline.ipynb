# %%
import joblib
import numpy as np
import pandas as pd

# %%
pipe=joblib.load('pipe.pkl')

# %%
# Assume user input
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
df_test = pd.DataFrame(test_input2, columns=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
pred = pipe.predict(df_test)[0]

# %%
pred
# Out:
# np.int64(0)
